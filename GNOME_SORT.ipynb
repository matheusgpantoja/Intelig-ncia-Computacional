# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusgpantoja/Inteligencia-Computacional/blob/main/GNOME_SORT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matheus Gabriel Gomes Pantoja
#
#
# Richard Douglas Da Piedade Soares

# %%
import numpy  as np
import time
import random

# %% [markdown]
# ## Apresentaçao

# %%
def gnome_sort(array):
    for position in range(1, len(array)):
        while position != 0 and array[position] < array[position - 1]:
            array[position], array[position - 1] = array[position - 1], array[position]
            position = position - 1

    return array

# %%
# %%time
gnome_sort([12,9,10,-2])
# Out:
# CPU times: user 9 µs, sys: 1e+03 ns, total: 10 µs
# Wall time: 14.3 µs
# [-2, 9, 10, 12]

# %%
# Gera m números aleatórios inteiros na lista
n = 10000

# lista aleatorio
lista_aleatoria = [random.randint(-10e2, 10e2) for i in range(n)]
print(f'Lista aleatórioa: {lista_aleatoria}')
# Out:
# Lista aleatórioa: [-111, -214, 660, 573, -68, -136, 243, 52, -583, 3, 992, 486, 432, -584, 480, -134, -199, -273, 963, 960, -116, 282, -243, 977, -244, -484, 363, -756, -414, 304, -98, -632, 815, 561, -150, 420, -659, -29, 675, 686, -967, -913, 796, 856, 422, -871, -504, -679, -911, 804, 810, -481, 684, 578, -85, -383, -593, -308, -2, -374, -806, -782, -337, -285, 555, -897, 763, -432, -140, -475, -835, -318, -157, 832, -216, 602, 178, -524, -583, 759, -253, -443, 139, 629, 920, -113, 133, 486, -93, 309, 620, 353, 146, 83, 450, 172, 657, 830, -748, 84, 406, -13, -44, -604, 976, 908, 175, -126, -515, -403, -68, 124, -544, 302, 649, 390, -285, -856, -57, 131, -95, -752, -100, 557, -703, -282, -96, -190, -783, 736, 568, 758, 857, -950, -931, 423, -640, -386, -988, 464, 486, -247, 989, 582, -379, 947, 950, -951, -352, 10, 252, -550, 64, 710, -362, 992, -457, 660, -773, -123, -581, 433, -747, 554, -529, -773, -249, -917, -25, 444, 284, -269, 734, 775, 107, -185, 609, 261, -921, 911, 193, 202, 850, 356, 889, -753, 697, 290, -1, -559, -196, -919, 698, -808, -57, -552, 873, -750, -173, 153, -923, 963, 19, -794, -784, 390, -390, 935, -730, -255, 151, -518, 950, 87, -27, 889, -839, 64, -315, 970, -363, 611, -439, -647, -362, 245, -33, 129, 639, 390, -916, 107, -533, 194, 725, -330, -220, -344, -877, 248, -751, 726, 582, 976, -718, 727, -229, 539, 615, 611, 407, -869, 111, -741, 840, 876, 539, 261, -517, -217, -186, -425, -465, 508, -906, 514, 700, 933, 66, -344, 989, -503, 831, -266, 378, 764, -869, 910, 529, -852, 921, -228, 320, -747, -60, -501, 753, 979, 995, -657, -990, -243, -354, 14, -796, 623, 204, -611, -415, 474, -83, 451, 354, -182, -202, 764, 15, -675, -572, 236, -732, -480, 279, -87, -735, -633, -393, 836, 916, 768, 82, -278, 921, 336, -519, -599, -760, -174, 839, -377, -901, 347, 368, -51, 993, 592, -214, -724, 77, 98, 432, 449, -46, -411, 75, -118, 730, 720, -549, -993, 510, 619, -260, 863, 477, -360, -824, -593, -888, 624, 617, -640, -900, -615, -692, -905, -959, 747, -506, 335, -145, -770, 841, -405, -758, 137, -522, -757, 185, -933, 553, 340, -198, -74, 784, -114, -778, 502, -631, -805, 145, 787, -993, -537, 528, 757, 992, 710, 212, -167, 591, 708, 911, -972, 621, -108, 935, -26, -343, 903, -847, -872, 129, 972, 290, 86, 548, -509, 63, 741, 620, 155, -772, -395, -281, 692, 376, 475, 625, -753, 883, -53, 383, 125, -566, -27, 805, -422, 264, 867, -620, -224, 63, 609, -18, 998, 938, -700, 391, 279, -750, -456, 44, -185, -315, 101, -5, 82, -956, -3, 32, 377, -15, -821, -650, -206, 223, 608, 900, 254, -454, 719, 838, -660, -817, 423, -526, 937, 955, 520, 705, 839, 732, 321, -836, 447, 271, 470, 659, 618, -445, 39, 966, 313, 394, -61, -919, 332, 602, -806, 955, 465, -669, 183, 288, -124, 728, 328, -677, 529, 331, -315, -93, -916, 500, 145, -588, 101, -284, -202, -900, 845, -73, 546, 398, 38, -126, -684, 391, 422, -987, 826, -473, 805, 771, 942, 916, -741, 458, -564, 870, 290, -339, 29, -111, 136, -71, 134, 557, 787, 580, -885, -913, 271, 246, -414, 482, 421, -283, 588, 184, 563, 382, 545, -404, -851, -574, 761, 89, 245, 518, -340, 689, -585, 607, 111, 881, 822, -513, 293, 869, 625, -29, -177, -538, 661, -821, 167, 687, -674, -919, -552, -905, 144, 721, -671, 574, -809, -556, 926, -884, 459, 137, 119, -977, -980, -79, -981, -365, 860, 916, 596, -403, 75, -44, -166, 179, -20, -573, -133, 674, 148, 951, 401, 812, 305, -131, -21, -711, 346, 538, 649, 224, -308, -431, 32, -192, 973, -673, -198, -282, -828, 314, -804, 712, -841, -322, 131, 411, -581, -325, -507, 514, 999, 369, -289, 944, -542, 631, 380, -462, -73, 825, -708, -565, 633, -123, 184, -680, -428, 94, 532, -767, 530, -986, 189, -848, 948, 327, 905, 204, -583, 513, 503, 48, 330, -283, 859, -551, 252, -610, 73, 522, 883, 604, 317, 360, 914, -258, -678, 160, 233, 30, -863, -191, -581, 886, -963, -254, 918, -297, 308, 564, 590, -372, 229, -27, 516, -784, -926, -539, -494, 630, 251, -903, -149, -608, -723, 397, -958, -448, -289, -632, -86, -630, 538, 860, 368, -282, -127, 738 ...

# %%
# %%time
gnome_sort(lista_aleatoria)

# %% [markdown]
# ## Testes

# %%
def gnome_sort(array):
    comparisons = 0
    swaps = 0

    for position in range(1, len(array)):
        while position != 0 and array[position] < array[position - 1]:
            array[position], array[position - 1] = array[position - 1], array[position]
            position = position - 1
            swaps += 1
            comparisons += 1

        comparisons += 1

    # print("Número de comparações:", comparisons)
    # print("Número de trocas:", swaps)

    return array,comparisons,swaps

# %% [markdown]
# ### Vetor de 10 posições

# %%
import random

# Gera 10 números aleatórios inteiros e coloca na lista
n = 10

# lista aleatorio
lista_aleatoria = [random.randint(-10e5, 10e5) for i in range(n)]
print(f'Lista aleatórioa: {lista_aleatoria}')

#lista crescente
# lista_crescente = int(random.sample(range(-1000, 10e5), n))
lista_crescente = [random.randint(-10e5, 10e5) for i in range(n)]
lista_crescente.sort()
print(f'\nLista crescente: {lista_crescente}')

#lista decrescente
# lista_decrescente = random.sample(range(-1000, 10e5), n)
lista_decrescente = [random.randint(-10e5, 10e5) for i in range(n)]
lista_decrescente.sort(reverse=True)
print(f'\nLista decrescente: {lista_decrescente}')

# %% [markdown]
# #### Aleatoria

# %%
# %%time
gnome_sort(lista_aleatoria)

# %% [markdown]
# #### Crescente

# %%
# %%time
gnome_sort(lista_crescente)

# %% [markdown]
# #### Decrescente

# %%
# %%time
gnome_sort(lista_decrescente)

# %% [markdown]
# ### Vetor de 1000 posições

# %%
import random

# Gera 10 números aleatórios inteiros e coloca na lista
n = 1000

# lista aleatorio
lista_aleatoria = [random.randint(-10e2, 10e2) for i in range(n)]
print(f'Lista aleatórioa: {lista_aleatoria}')

#lista crescente
# lista_crescente = int(random.sample(range(-1000, 10e5), n))
lista_crescente = [random.randint(-10e2, 10e2) for i in range(n)]
lista_crescente.sort()
print(f'\nLista crescente: {lista_crescente}')

#lista decrescente
# lista_decrescente = random.sample(range(-1000, 10e5), n)
lista_decrescente = [random.randint(-10e2, 10e2) for i in range(n)]
lista_decrescente.sort(reverse=True)
print(f'\nLista decrescente: {lista_decrescente}')

# %% [markdown]
# #### Aleatoria

# %%
# %%time
gnome_sort(lista_aleatoria)

# %% [markdown]
# #### Crescente

# %%
# %%time
gnome_sort(lista_crescente)

# %% [markdown]
# #### Decrescente

# %%
# %%time
gnome_sort(lista_decrescente)

# %% [markdown]
# ### 10.000 posições

# %%
def gnome_sort(array):
    comparisons = 0
    swaps = 0

    for position in range(1, len(array)):
        while position != 0 and array[position] < array[position - 1]:
            array[position], array[position - 1] = array[position - 1], array[position]
            position = position - 1
            swaps += 1
            comparisons += 1

        comparisons += 1

    # print("Número de comparações:", comparisons)
    # print("Número de trocas:", swaps)

    return comparisons,swaps

# %%
import random

# Gera 10 números aleatórios inteiros e coloca na lista
n = 10000

# lista aleatorio
lista_aleatoria = [random.randint(-10e2, 10e2) for i in range(n)]
print(f'Lista aleatórioa: {lista_aleatoria}')

#lista crescente
# lista_crescente = int(random.sample(range(-1000, 10e5), n))
lista_crescente = [random.randint(-10e2, 10e2) for i in range(n)]
lista_crescente.sort()
print(f'\nLista crescente: {lista_crescente}')

#lista decrescente
# lista_decrescente = random.sample(range(-1000, 10e5), n)
lista_decrescente = [random.randint(-10e2, 10e2) for i in range(n)]
lista_decrescente.sort(reverse=True)
print(f'\nLista decrescente: {lista_decrescente}')

# %% [markdown]
# #### Aleatorio

# %%
# %%time
gnome_sort(lista_aleatoria)

# %% [markdown]
# #### Crescente

# %%
# %%time
gnome_sort(lista_crescente)

# %% [markdown]
# #### Decrescente

# %%
# %%time
gnome_sort(lista_decrescente)

# %%
def gnome_sort(array):
    comparisons = 0
    swaps = 0

    for position in range(1, len(array)):
        while position != 0 and array[position] < array[position - 1]:
            print(f'posição atual:{position} dentro')
            array[position], array[position - 1] = array[position - 1], array[position]
            position = position - 1
            swaps += 1
            comparisons += 1
            print(array[position])
            print(f'comp atual:{comparisons}')
            print(f'swqp atual:{swaps}\n')

        comparisons += 1
        print(f'posição atual:{position} fora')
        print(f'comp atual:{comparisons}')
        print(f'swqp atual:{swaps}\n')
    # print("Número de comparações:", comparisons)
    # print("Número de trocas:", swaps)

    return array,comparisons,swaps
